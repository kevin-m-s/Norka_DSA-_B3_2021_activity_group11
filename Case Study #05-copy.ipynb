# %% [markdown]
# # Case Study on ANOVA
#
# XYZ Company has offices in four different zones. The company wishes to investigate the following :
#
# - The mean sales generated by each zone.
# - Total sales generated by all the zones for each month.
# - Check whether all the zones generate the same amount of sales.
#
# Help the company to carry out their study with the help of data provided.

# %%
#importing pandas,numply,matplotlib.pyplot,seaborn libaries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Reading the dataset to the python environment
data=pd.read_csv('Sales_data_zone_wise.csv')

# %%
#displaying  top 5  rows of the dataset
data.head()
# Out:
#        Month  Zone - A  Zone - B  Zone - C  Zone - D
# 0  Month - 1   1483525   1748451   1523308   2267260
# 1  Month - 2   1238428   1707421   2212113   1994341
# 2  Month - 3   1860771   2091194   1282374   1241600
# 3  Month - 4   1871571   1759617   2290580   2252681
# 4  Month - 5   1244922   1606010   1818334   1326062

# %%
#To know data types of each columns and checking for null values in the columns
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Month     29 non-null     object
#  1   Zone - A  29 non-null     int64
#  2   Zone - B  29 non-null     int64
#  3   Zone - C  29 non-null     int64
#  4   Zone - D  29 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 1.3+ KB

# %% [markdown]
# <div class="alert alert-block alert-info"><b>Note:</b><br>
#
# - It appears that we do not have empty/NaN values in the dataset,as the number of Non-Null counts for each column is equal to 29, which is exactly the number of rows in the dataset.<br>
# - We also note that our numeric data are detected as integer values.
# </div>

# %%
#Check for the null values present in each column of  dataset using 'isnull().sum()' function
data.isnull().sum()
# Out:
# Month       0
# Zone - A    0
# Zone - B    0
# Zone - C    0
# Zone - D    0
# dtype: int64

# %% [markdown]
# **Note-**
#
# No  <mark>Null values <mark>

# %%
# to know  statistical summary of integer datatype columns 
data.describe()
# Out:
#            Zone - A      Zone - B      Zone - C      Zone - D
# count  2.900000e+01  2.900000e+01  2.900000e+01  2.900000e+01
# mean   1.540493e+06  1.755560e+06  1.772871e+06  1.842927e+06
# std    2.619401e+05  1.683899e+05  3.331937e+05  3.750165e+05
# min    1.128185e+06  1.527574e+06  1.237722e+06  1.234311e+06
# 25%    1.305972e+06  1.606010e+06  1.523308e+06  1.520406e+06
# 50%    1.534390e+06  1.740365e+06  1.767047e+06  1.854412e+06
# 75%    1.820196e+06  1.875658e+06  2.098463e+06  2.180416e+06
# max    2.004480e+06  2.091194e+06  2.290580e+06  2.364132e+06

# %% [markdown]
# ## The company wishes to investigate  :
# ### 1. The mean sales generated by each zone.

# %%
data.mean()
# Out:
# Zone - A    1.540493e+06
# Zone - B    1.755560e+06
# Zone - C    1.772871e+06
# Zone - D    1.842927e+06
# dtype: float64

# %%
print("Mean of Zone - A",round(data['Zone - A'].mean(),2))
print("Mean of Zone - B",round(data['Zone - B'].mean(),2))
print("Mean of Zone - C",round(data['Zone - C'].mean(),2))
print("Mean of Zone - D",round(data['Zone - D'].mean(),2))
# Out:
# Mean of Zone - A 1540493.14
# Mean of Zone - B 1755559.59
# Mean of Zone - C 1772871.03
# Mean of Zone - D 1842926.76

# %%
print("Mean of each zone\n ",round(data.mean(),2))
# Out:
# Mean of each zone
#   Zone - A    1540493.14
# Zone - B    1755559.59
# Zone - C    1772871.03
# Zone - D    1842926.76
# dtype: float64

# %% [markdown]
# #use this

# %%
data.agg(['std','mean',]).round(3)
# Out:
#          Zone - A     Zone - B     Zone - C     Zone - D
# std    261940.062   168389.886   333193.725   375016.479
# mean  1540493.138  1755559.586  1772871.034  1842926.759

# %% [markdown]
# <div class="alert alert-block alert-info"><b>Note:</b><br>
#
# - mean sales generated by  Zone-D is higher.<br>
# - mean sales generated by  Zone-A is lower.
# </div>

# %% [markdown]
# ## The company wishes to investigate  :
# ### 2.Total sales generated by all the zones for each month.

# %%
data["Total sales"] = data.sum(axis=1)
data
# Out:
#          Month  Zone - A  Zone - B  Zone - C  Zone - D  Total sales
# 0    Month - 1   1483525   1748451   1523308   2267260      7022544
# 1    Month - 2   1238428   1707421   2212113   1994341      7152303
# 2    Month - 3   1860771   2091194   1282374   1241600      6475939
# 3    Month - 4   1871571   1759617   2290580   2252681      8174449
# 4    Month - 5   1244922   1606010   1818334   1326062      5995328
# 5    Month - 6   1534390   1573128   1751825   2292044      7151387
# 6    Month - 7   1820196   1992031   1786826   1688055      7287108
# 7    Month - 8   1625696   1665534   2161754   2363315      7816299
# 8    Month - 9   1652644   1873402   1755290   1422059      6703395
# 9   Month - 10   1852450   1913059   1754314   1608387      7128210
# 10  Month - 11   2004480   1740365   1317869   1970069      7032783
# 11  Month - 12   1537539   1875658   1237722   1460165      6111084
# 12  Month - 13   1254939   1588473   1348629   1733383      5925424
# 13  Month - 14   1821799   1844081   1617376   1872259      7155515
# 14  Month - 15   1128185   1804613   1767047   1234311      5934156
# 15  Month - 16   1491534   1542053   1882159   1590913      6506659
# 16  Month - 17   1182110   1552388   2234469   2180416      7149383
# 17  Month - 18   1770324   1699213   1249821   2364132      7083490
# 18  Month - 19   1181635   1959268   2009168   1821882      6971953
# 19  Month - 20   1305972   1559670   2107949   2151008      7124599
# 20  Month - 21   1570152   2013615   1540016   2265814      7389597
# 21  Month - 22   1481619   1527574   2255729   2295079      7560001
# 22  Month - 23   1887694   1992155   1348387   1459683      6687919
# 23  Month - 24   1880820   1752873   2098463   2052591      7784747
# 24  Month - 25   1256333   1622671   1521792   1695122      6095918
# 25  Month - 26   1422853   1715465   1853636   1520406      6512360
# 26  Month - 27   1384426   1983163   1611169   1289160      6267918
# 27  Month - 28   1616640   1547991   2128022   2178267      7470920
# 28  Month - 29   1310654   1660092   1947119   1854412      6772277

# %%
data['Total Sales']=data.iloc[:,0:5].sum(axis=1)
data
# Out:
#          Month  Zone - A  Zone - B  Zone - C  Zone - D  Total sales    total  \
# 0    Month - 1   1483525   1748451   1523308   2267260      7022544  7022544
# 1    Month - 2   1238428   1707421   2212113   1994341      7152303  7152303
# 2    Month - 3   1860771   2091194   1282374   1241600      6475939  6475939
# 3    Month - 4   1871571   1759617   2290580   2252681      8174449  8174449
# 4    Month - 5   1244922   1606010   1818334   1326062      5995328  5995328
# 5    Month - 6   1534390   1573128   1751825   2292044      7151387  7151387
# 6    Month - 7   1820196   1992031   1786826   1688055      7287108  7287108
# 7    Month - 8   1625696   1665534   2161754   2363315      7816299  7816299
# 8    Month - 9   1652644   1873402   1755290   1422059      6703395  6703395
# 9   Month - 10   1852450   1913059   1754314   1608387      7128210  7128210
# 10  Month - 11   2004480   1740365   1317869   1970069      7032783  7032783
# 11  Month - 12   1537539   1875658   1237722   1460165      6111084  6111084
# 12  Month - 13   1254939   1588473   1348629   1733383      5925424  5925424
# 13  Month - 14   1821799   1844081   1617376   1872259      7155515  7155515
# 14  Month - 15   1128185   1804613   1767047   1234311      5934156  5934156
# 15  Month - 16   1491534   1542053   1882159   1590913      6506659  6506659
# 16  Month - 17   1182110   1552388   2234469   2180416      7149383  7149383
# 17  Month - 18   1770324   1699213   1249821   2364132      7083490  7083490
# 18  Month - 19   1181635   1959268   2009168   1821882      6971953  6971953
# 19  Month - 20   1305972   1559670   2107949   2151008      7124599  7124599
# 20  Month - 21   1570152   2013615   1540016   2265814      7389597  7389597
# 21  Month - 22   1481619   1527574   2255729   2295079      7560001  7560001
# 22  Month - 23   1887694   1992155   1348387   1459683      6687919  6687919
# 23  Month - 24   1880820   1752873   2098463   2052591      7784747  7784747
# 24  Month - 25   1256333   1622671   1521792   1695122      6095918  6095918
# 25  Month - 26   1422853   1715465   1853636   1520406      6512360  6512360
# 26  Month - 27   1384426   1983163   1611169   1289160      6267918  6267918
# 27  Month - 28   1616640   1547991   2128022   2178267      7470920  7470920
# 28  Month - 29   1310654   1660092   1947119   1854412      6772277  6772277
#
#     Total Sales
# 0       7022544
# 1       7152303
# 2       6475939
# 3       8174449
# 4       5995328
# 5       7151387
# 6       7287108
# 7       7816299
# 8       6703395
# 9       7128210
# 10      7032783
# 11      6111084
# 12      5925424
# 13      7155515
# 14      5934156
# 15      6506659
# 16      7149383
# 17      7083490
# 18      6971953
# 19      7124599
# 20      7389597
# 21      7560001
# 22      6687919
# 23      7784747
# 24      6095918
# 25      6512360
# 26      6267918
# 27      7470920
# 28      6772277

# %%
#zones = ['Zone - A', 'Zone - B', 'Zone - C', 'Zone - D']
#df['Total_Sales'] = df[zones].sum(axis=1)
#df

# %%
data['Total Sales'].sort_values()
# Out:
# 12    5925424
# 14    5934156
# 4     5995328
# 24    6095918
# 11    6111084
# 26    6267918
# 2     6475939
# 15    6506659
# 25    6512360
# 22    6687919
# 8     6703395
# 28    6772277
# 18    6971953
# 0     7022544
# 10    7032783
# 17    7083490
# 19    7124599
# 9     7128210
# 16    7149383
# 5     7151387
# 1     7152303
# 13    7155515
# 6     7287108
# 20    7389597
# 27    7470920
# 21    7560001
# 23    7784747
# 7     7816299
# 3     8174449
# Name: Total Sales, dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-info"><b>Find:</b><br>
#
# - Highest Total Sales was  generated in month-4 .<br>
# - Lowest  Total Sales was  generated in month-13.
# </div>

# %% [markdown]
# ## The company wishes to investigate  :
# ### 3.Check whether all the zones generate the same amount of sales.

# %% [markdown]
# We check whether all the zones generate the same amount of sales using **ANOVA Test**<br>
# even though there are 3 or more groups being tested , those groups are under one categorical variable so we use **One-way ANOVA Test.**

# %% [markdown]
# >Set the hypothesis

# %% [markdown]
# Null Hypothesis (H0):  all the zones generate the same amount of sales
#
# Alternate Hypothesis (H1): all the zones does not generate the same amount of sales.

# %% [markdown]
# >Set the significance level

# %% [markdown]
# Significance level,α= 0.05

# %% [markdown]
# >One-way ANOVA Test.

# %%
from scipy import stats

F, p = stats.f_oneway(data['Zone - A'], data['Zone - B'], data['Zone - C'],data['Zone - D'])
print('F-value:',round(F,4),'p-value:',round(p,4))
# Out:
# F-value: 5.6721 p-value: 0.0012

# %%
if p > 0.05:
    print('Null Hypothesis is proved')
else :
    print ('Alternate Hypothesis is proved')
# Out:
# Alternate Hypothesis is proved

# %% [markdown]
# >Making a Decision

# %% [markdown]
# <div class="alert alert-block alert-info"><b>Find:</b><br>
#
# From the Ttest performed,<br>
#
# p-value(=0.001) < alpha(=0.05)<br>
#
# We `reject the null hypothesis H0`<br>
#
# So we conclude that , all the zones does not generate the same amount of sales..
#
# </div>

# %%
FInd-
