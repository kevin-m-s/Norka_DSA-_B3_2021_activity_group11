# %% [markdown]
# # Week 7 Activity
#      1. Read the data into python
#      2. Check for null values
#      3. Examine the variables ‘Hardness’, ‘Sulfate’, and ‘Organic_carbon’ and comment on your observations.
#      4. Carry out correlation analysis on the dataset and find the correlation factor between
#        a. ph and Chloramines
#        b. ph and Conductivity
#        What do we infer from this correlation value?

# %%
#importing pandas,numply,matplotlib.pyplot,seaborn libaries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 1.Read the data into python

# %%
#Reading the dataset to the python environment
data=pd.read_csv('Week_7_Activity_data.csv')

# %%
#displaying  top 5  rows of the dataset
data.head()
# Out:
#           ph    Hardness       Solids  Chloramines     Sulfate  Conductivity  \
# 0   8.316766  214.373394  22018.41744     8.059332  356.886136    363.266516
# 1   9.092223  181.101509  17978.98634     6.546600  310.135738    398.410813
# 2   5.584087  188.313324  28748.68774     7.544869  326.678363    280.467916
# 3  10.223862  248.071735  28749.71654     7.513408  393.663395    283.651634
# 4   8.635849  203.361523  13672.09176     4.563009  303.309771    474.607645
#
#    Organic_carbon  Trihalomethanes  Turbidity
# 0       18.436525       100.341674   4.628771
# 1       11.558279        31.997993   4.075075
# 2        8.399735        54.917862   2.559708
# 3       13.789695        84.603556   2.672989
# 4       12.363817        62.798309   4.401425

# %% [markdown]
# ### 2. Check for null values

# %%
#Check for the null values present in each column of  dataset using 'isnull().sum()' function
data.isnull().sum()
# Out:
# ph                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Sulfate            0
# Conductivity       0
# Organic_carbon     0
# Trihalomethanes    0
# Turbidity          0
# dtype: int64

# %% [markdown]
# Find-
#
# No null values

# %%
#To know data types of each columns and checking for null values in the columns
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2011 entries, 0 to 2010
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2011 non-null   float64
#  1   Hardness         2011 non-null   float64
#  2   Solids           2011 non-null   float64
#  3   Chloramines      2011 non-null   float64
#  4   Sulfate          2011 non-null   float64
#  5   Conductivity     2011 non-null   float64
#  6   Organic_carbon   2011 non-null   float64
#  7   Trihalomethanes  2011 non-null   float64
#  8   Turbidity        2011 non-null   float64
# dtypes: float64(9)
# memory usage: 141.5 KB

# %%
# to know  statistical summary of integer datatype columns 
data.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  2011.000000  2011.000000   2011.000000  2011.000000  2011.000000
# mean      7.085990   195.968072  21917.441375     7.134338   333.224672
# std       1.573337    32.635085   8642.239815     1.584820    41.205172
# min       0.227499    73.492234    320.942611     1.390871   129.000000
# 25%       6.089723   176.744938  15615.665390     6.138895   307.632511
# 50%       7.027297   197.191839  20933.512750     7.143907   332.232177
# 75%       8.052969   216.441070  27182.587065     8.109726   359.330555
# max      14.000000   317.338124  56488.672410    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity
# count   2011.000000     2011.000000      2011.000000  2011.000000
# mean     426.526409       14.357709        66.400859     3.969729
# std       80.712572        3.324959        16.077109     0.780346
# ...

# %% [markdown]
# ### 3. Examine the variables ‘Hardness’, ‘Sulfate’, and ‘Organic_carbon’ and comment on your observations.

# %%
data[['Hardness','Sulfate','Organic_carbon']].describe()
# Out:
#           Hardness      Sulfate  Organic_carbon
# count  2011.000000  2011.000000     2011.000000
# mean    195.968072   333.224672       14.357709
# std      32.635085    41.205172        3.324959
# min      73.492234   129.000000        2.200000
# 25%     176.744938   307.632511       12.124105
# 50%     197.191839   332.232177       14.322019
# 75%     216.441070   359.330555       16.683049
# max     317.338124   481.030642       27.006707

# %% [markdown]
# Find-
#
# Mean & standard deviation is higher for Sulfate than Hardness & Organic_carbon

# %%
sns.pairplot(data[['Hardness','Sulfate','Organic_carbon']])
plt.show()

# %%
sns.distplot(data['Hardness'],kde = False)
plt.title('Distribution of Hardness')
import warnings
warnings.filterwarnings('ignore')

# %%
sns.distplot(data['Sulfate'],kde = False)
plt.title('Distribution of Sulfate')
import warnings
warnings.filterwarnings('ignore')

# %%
sns.distplot(data['Organic_carbon'],kde = False)
plt.title('Distribution of Organic carbon')
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Observation-
#
# All three variables are normally distributed

# %%
corrmatrix=data.corr()
plt.subplots(figsize=(20,8))
sns.heatmap(corrmatrix,vmin=-.2 ,annot=True,linewidths=0.2,cmap="YlGnBu")
# Out:
# <AxesSubplot:>

# %% [markdown]
# Observation-
#
#      The correlation value of sulfate with Organic carbon is 0.027,
#                               Organic carbon with hardness is 0.013.
#                               hardness with sulfate is -0.11.
#      Hardness have a high correlation of 0.11 with ph
#      Hardness have a low  correlation of -0.11 with sulfate
#      sulfate have a lowest correlation of -0.16 with Solids

# %% [markdown]
# ### 4. Carry out correlation analysis on the dataset and find the correlation factor between
#      a. ph and Chloramines
#      b. ph and Conductivity
#      What do we infer from this correlation value?

# %% [markdown]
# **a. ph and Chloramines**

# %%
data[['ph','Chloramines']].corr()
# Out:
#                    ph  Chloramines
# ph           1.000000    -0.024768
# Chloramines -0.024768     1.000000

# %%
from scipy.stats import pearsonr
corr2, _ = pearsonr(data['Chloramines'], data['ph'])
print('Pearsons correlation: %.4f' % corr2)
# Out:
# Pearsons correlation: -0.0248

# %% [markdown]
# Observation-
#
# ph & Chloramines has a negative correlation (ie -0.0248)

# %% [markdown]
# **b. ph and Conductivity**

# %%
data[['ph','Conductivity']].corr()
# Out:
#                     ph  Conductivity
# ph            1.000000      0.014128
# Conductivity  0.014128      1.000000

# %%
corr3, _ = pearsonr(data['ph'], data['Conductivity'])
print('Pearsons correlation: %.4f' % corr3)
# Out:
# Pearsons correlation: 0.0141

# %% [markdown]
# Observation-
#
# ph & Conductivity has a low positive  correlation of 0.0141
